# %%
import sys

# %%
import pathlib
p=str(pathlib.Path("__file__").parent.resolve())
pp=p.split("\\")
p="\\".join(pp)

sys.path.append(p)

# %%
import pathlib
str(pathlib.Path().resolve())
# Out:
# 'C:\\Users\\Mohammad Arshad Ali\\Dropbox\\Programming\\KMIT\\Projects\\group\\python project on dataset (1st year 2nd sem)\\github_repo\\python_project-dataset\\rough_work'

# %%
sys.path.append(r"C:\Users\Mohammad Arshad Ali\Dropbox\Programming\KMIT\Projects\group\python project on dataset (1st year 2nd sem)\github_repo\python_project-dataset")

# %%
p
# Out:
# 'C:\\Users\\Mohammad Arshad Ali\\Dropbox\\Programming\\KMIT\\Projects\\group\\python project on dataset (1st year 2nd sem)\\github_repo\\python_project-dataset\\rough_work'

# %%
p
# Out:
# ['C:',
#  'Users',
#  'Mohammad Arshad Ali',
#  'Dropbox',
#  'Programming',
#  'KMIT',
#  'Projects',
#  'group',
#  'python project on dataset (1st year 2nd sem)',
#  'github_repo',
#  'python_project-dataset',
#  'rough_work']

# %%
ind=len(pp)-1-(pp[::-1].index("python_project-dataset"))

# %%
base_path="\\".join(pp[:ind+1])

# %%
base_path+r"\Files\college_info\branch\courses_detail.json"
# Out:
# 'C:\\Users\\Mohammad Arshad Ali\\Dropbox\\Programming\\KMIT\\Projects\\group\\python project on dataset (1st year 2nd sem)\\github_repo\\python_project-dataset\\Files\\college_info\\branch\\courses_detail.json'

# %%
from colleges import *

# %%
College.calculate_dist((17.39710069782906, 78.49003054943614))
# Out:
# (College(KMIT), College(OUCE), College(OUCT))

# %%
College.graph()

# %%
from colleges import *

# %%
KMIT.placement_info
# Out:
# {'highest_salary': 44.0,
#  'lowest_salary': 3.0,
#  'salary_mode': 4.0,
#  'salary_mean': 6.86820415879017,
#  'salary_median': 5.5,
#  'total_offers': 1058,
#  'compaies_visited': 110,
#  'placement_data_year': 2022,
#  'placement_percent': 135.64}
